# %% [markdown]
# # Task 8 - CNN Architectures
#
# In this assignment you will practice in replicating famous Convolutional Neural Network Architectures that won the IMAGENET Challange using Keras and TensorFlow.
#
# The goals of this assignment are as follows:
# * understand the architecture advantages
# * implement and train LeNet-5 on CIFAR-10
# * implement AlexNet
# * implement and train small AlexNet on CIFAR-10
# * implement ZF-Net
# * implement VGG Net
# * implement and train small VGG on CIFAR-10
# * implement and train small Inception Network on CIFAR-10
# * implement and train small Residual Network on CIFAR-10

# %% [markdown]
# ---
# ---
# #[Part 0] Import Libraries and Load Data

# %% [markdown]
# ---
# ## 1 - Import Libraries
# Import required libraries

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import backend as K
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D, AveragePooling2D
from tensorflow.keras.layers import BatchNormalization, Dropout, ZeroPadding2D
from tensorflow.keras.layers import GlobalAveragePooling2D

from tensorflow.keras.regularizers import l2

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import plot_model

# %matplotlib inline

# %% [markdown]
# Write down your Name and Student ID

# %%
# ## --- start your code here ----

NIM = "Muhammad Luthfi Harwidjaya"
Nama = "21/476813/PA/20606"

# ## --- end your code here ----

# %% [markdown]
# ---
# ## 2 - Load CIFAR-10

# %%
(X_train_ori, y_train), (X_test_ori, y_test) = tf.keras.datasets.cifar10.load_data()

class_names = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# ---
# ## 3 - Split Validation Data

# %%
X_val_ori   = X_train_ori[-10000:,:]
y_val       = y_train[-10000:]

X_train_ori = X_train_ori[:-10000, :]
y_train     = y_train[:-10000]

# %% [markdown]
# ---
# ## 4 - Normalize and Reshape Data

# %%
X_train    = X_train_ori.astype('float32')
X_val      = X_val_ori.astype('float32')
X_test     = X_test_ori.astype('float32')

mean_image = X_train.mean(axis=(0, 1, 2), keepdims=True)
std_image  = X_train.std(axis=(0, 1, 2), keepdims=True)

X_train    = (X_train - mean_image) /std_image
X_val      = (X_val - mean_image) /std_image
X_test     = (X_test - mean_image) /std_image

X_train    = X_train.astype('float32')
X_val      = X_val.astype('float32')
X_test     = X_test.astype('float32')

print('X_train.shape =',X_train.shape)
print('X_val.shape   =',X_val.shape)
print('X_test.shape  =',X_test.shape)

y_train = y_train.ravel()
y_val   = y_val.ravel()
y_test  = y_test.ravel()

print('\ny_train.shape =',y_train.shape)
print('y_val.shape   =',y_val.shape)
print('y_test.shape  =',y_test.shape)
# Out:
# X_train.shape = (40000, 32, 32, 3)
# X_val.shape   = (10000, 32, 32, 3)
# X_test.shape  = (10000, 32, 32, 3)
#
# y_train.shape = (40000,)
# y_val.shape   = (10000,)
# y_test.shape  = (10000,)

# %% [markdown]
# one hot the label

# %%
y_train_hot = to_categorical(y_train, 10)
y_val_hot   = to_categorical(y_val, 10)
y_test_hot  = to_categorical(y_test, 10)

print('y_train_hot.shape =',y_train_hot.shape)
print('y_val_hot.shape   =',y_val_hot.shape)
print('y_test_hot.shape  =',y_test_hot.shape)
# Out:
# y_train_hot.shape = (40000, 10)
# y_val_hot.shape   = (10000, 10)
# y_test_hot.shape  = (10000, 10)

# %% [markdown]
# ---
# ## 5 - Helper Functions
# train-val loss and accuracy plot helper function

# %%
def plot_my_history(history):
  plt.rcParams['figure.figsize'] = [14, 3.5]
  plt.subplots_adjust(wspace=0.2)

  plt.subplot(121)
  # Plot training & validation accuracy values
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'])

  plt.subplot(122)
  # Plot training & validation loss values
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Test'])
  plt.show()

# %% [markdown]
# ---
# # [Part 1] Shallow 4-Layer Neural Net
# Here you will complete the implementation of 4-Layer Neural Network, just as comparison.

# %% [markdown]
# ---
# ## 1 - Define Model
#
# Define the 4-layer Neural net

# %% [markdown]
# ---
# #### <font color='red'>**EXERCISE:** </font>
#
# <pre>
# Implement neuralnet() function
# the function will return neural net with architecture:
#     * the input shape is <font color='blue'><b>32x32x3</b></font>
#     * Flatten layer
#     * <font color='blue'><b>200</b></font> neurons in hidden layer 1 and 2 using relu activation
#     * <font color='blue'><b>100</b></font> neurons in hidden layer 3 also using relu activation
#     * <font color='blue'><b>10</b></font> neurons in output layer using softmax activation

# %%
def neuralnet():    
    return Sequential([

        # flatten input 32x32x3
        Flatten(input_shape=(32, 32, 3)),

        # dense 200 relu
        Dense(200, activation='relu'),

        # dense 200 relu
        Dense(200, activation='relu'),

        # dense 100 relu
        Dense(100, activation='relu'),

        # dense 10 softmax
        Dense(10, activation='softmax'),
        
    ], name="neuralnet")

# %% [markdown]
# ---
# ## 2 - Model Summary
# Visualize the model

# %%
model_nn = neuralnet()

model_nn.summary()
# Out:
# Model: "neuralnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 200)               614600
#
#  dense_1 (Dense)             (None, 200)               40200
#
#  dense_2 (Dense)             (None, 100)               20100
#
#  dense_3 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 675,910
# Trainable params: 675,910
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  Total params: 675,910
#  Trainable params: 675,910
#  Non-trainable params: 0

# %% [markdown]
# ---
# ## 3 - Plot Model
#
# Save model architecture as an image

# %%
  plot_model(model_nn, 
             to_file=model_nn.name+'.png', 
             show_shapes=True, 
             show_layer_names=False,
             dpi=70
            )

# %% [markdown]
# **EXPECTED IMAGE (rotated)**:
#
# <center>
#
# <img src="https://i.ibb.co/pfC2QJR/4layer.png" height=300>

# %% [markdown]
# ---
# ## 4 - Train Model
#
#
# Run the training process for `10 epochs`, with `batch size = 128`, using `Adam` Optimizer, and `'accuracy'` as its metric

# %%
num_epochs = 10
batch_size = 128

model_nn.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy']
)


history_nn = model_nn.fit(
    X_train, y_train_hot, 
    validation_data=(X_val, y_val_hot),
    epochs=num_epochs, 
    batch_size=batch_size, 
    verbose=2
)
# Out:
# Epoch 1/10
# 313/313 - 8s - loss: 1.7405 - accuracy: 0.3860 - val_loss: 1.6276 - val_accuracy: 0.4307 - 8s/epoch - 25ms/step
# Epoch 2/10
# 313/313 - 1s - loss: 1.5129 - accuracy: 0.4672 - val_loss: 1.5253 - val_accuracy: 0.4676 - 1s/epoch - 4ms/step
# Epoch 3/10
# 313/313 - 2s - loss: 1.4008 - accuracy: 0.5052 - val_loss: 1.4823 - val_accuracy: 0.4746 - 2s/epoch - 5ms/step
# Epoch 4/10
# 313/313 - 1s - loss: 1.3148 - accuracy: 0.5407 - val_loss: 1.4801 - val_accuracy: 0.4849 - 1s/epoch - 4ms/step
# Epoch 5/10
# 313/313 - 1s - loss: 1.2333 - accuracy: 0.5663 - val_loss: 1.4891 - val_accuracy: 0.4863 - 1s/epoch - 4ms/step
# Epoch 6/10
# 313/313 - 1s - loss: 1.1656 - accuracy: 0.5898 - val_loss: 1.4511 - val_accuracy: 0.5090 - 1s/epoch - 4ms/step
# Epoch 7/10
# 313/313 - 1s - loss: 1.1008 - accuracy: 0.6120 - val_loss: 1.4570 - val_accuracy: 0.5103 - 1s/epoch - 4ms/step
# Epoch 8/10
# 313/313 - 1s - loss: 1.0340 - accuracy: 0.6373 - val_loss: 1.5212 - val_accuracy: 0.5030 - 1s/epoch - 4ms/step
# Epoch 9/10
# 313/313 - 1s - loss: 0.9705 - accuracy: 0.6565 - val_loss: 1.5348 - val_accuracy: 0.5093 - 1s/epoch - 4ms/step
# Epoch 10/10
# 313/313 - 1s - loss: 0.9151 - accuracy: 0.6769 - val_loss: 1.5696 - val_accuracy: 0.5004 - 1s/epoch - 4ms/step

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  the loss should start around 1.7 and end around 0.9
#  with training accuracy start around 40% and end around 66%

# %% [markdown]
# ---
# ## 5 - Visualize Training History
#
# Visualzie the train-validation accuracy

# %%
plot_my_history(history_nn)

# %% [markdown]
# ---
# ## 6 - Evaluate Model
# Next, let's evaluate the accuracy of the models that have been trained
#
# we should get accuracy around  <font color='blue'>$50\%$</font>`

# %%
scores = model_nn.evaluate(X_test, y_test_hot, verbose=0)

print("\nModel Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Model Accuracy: 50.10%

# %% [markdown]
# ---
# ---
# # [Part 2] LeNet-5 (1998)
#
# Next you will implement [LeNet-5](http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf), the first successful application of convolutional networks, developed for handwritten digits and character recognition by LeCun et al., 1998
#
# The architecture consist of 5 layers (2 conv and 3 fc layers).
#
# The architecture visualization is as follows
#
# <br>
#
# <center>
# <img src="https://www.researchgate.net/profile/Vladimir_Golovko3/publication/313808170/figure/fig3/AS:552880910618630@1508828489678/Architecture-of-LeNet-5.png">

# %% [markdown]
# ---
# ## 1 - Define Model
#
# Define the LeNet-5
#
# The original network is using **tanh** activation function,
#
# but here, we'll use **relu**

# %% [markdown]
# ---
# #### <font color='red'>**EXERCISE:** </font>
# <pre>
# Implement <b>lenet5()</b> function
# the function will return <b>conv</b>olutional neural net with architecture:
#     * the input shape is <font color='blue'><b>32x32x3</b></font>
#     * <b>conv</b> layer with <font color='blue'><b>6</b></font> filters of <font color='blue'><b>5x5</b></font>, using relu activation
#     * <b>average pooling</b> with size <font color='blue'><b>2x2</b></font>
#
#     * <b>conv</b> layer with <font color='blue'><b>16</b></font> filters of <font color='blue'><b>5x5</b></font>, using relu activation
#     * <b>average pooling</b> with size <font color='blue'><b>2x2</b></font>
#     * flatten layer
#
#     * <b>dense</b> layer with <font color='blue'><b>120</b></font> neurons using relu activation
#     * <b>dense</b> layer with <font color='blue'><b>84</b></font> neurons using relu activation
#     * output <b>dense</b> layer with <font color='blue'><b>10</b></font> neuron using softmax activation

# %%
def lenet5():
    return Sequential([
        
        # conv 6 (5x5) relu, input 32x32x3
        Conv2D(6, (5, 5), activation='relu', input_shape=(32, 32, 3)),
        
        # avg pool (2x2)
        AveragePooling2D(),
        
        # conv 16 (5x5) relu
        Conv2D(16, (5, 5), activation='relu'),
        
        # avg pool (2x2)
        AveragePooling2D(),
        
        # flatten        
        Flatten(),
        
        # dense 120 relu
        Dense(120, activation='relu'),
        
        # dense 84 relu
        Dense(84, activation='relu'),
        
        # dense 10 softmax
        Dense(10, activation='softmax'),
        
    ], name="lenet5")

# %% [markdown]
# ---
# ## 2 - Model Summary
# Visualize the model

# %%
model_lenet = lenet5()

model_lenet.summary()
# Out:
# Model: "lenet5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 6)         456
#
#  average_pooling2d (AverageP  (None, 14, 14, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_1 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  flatten_1 (Flatten)         (None, 400)               0
#
#  dense_4 (Dense)             (None, 120)               48120
#
#  dense_5 (Dense)             (None, 84)                10164
#
#  dense_6 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 62,006
# Trainable params: 62,006
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  Total params: 62,006
#  Trainable params: 62,006
#  Non-trainable params: 0

# %% [markdown]
# ---
# ## 3 - Plot Model
#
# Save model architecture as an image

# %%
plot_model(model_lenet, 
           to_file=model_lenet.name+'.png', 
           show_shapes=True, 
           show_layer_names=False,
           rankdir='LR',
           dpi=70
          )

# %% [markdown]
# **EXPECTED IMAGE**:
#
# <center>
# <img src="https://i.ibb.co/n80BRC4/lenet5.png" width="90%"">

# %% [markdown]
# ---
# ## 4 - Train Model
#
#
# Run the training process for `10 epochs`, with `batch size = 128`, using `Adam` Optimizer, and `'accuracy'` as its metric

# %%
num_epochs = 10
batch_size = 128

model_lenet.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy']
)

history_lenet = model_lenet.fit(
    X_train, y_train_hot, 
    validation_data=(X_val, y_val_hot),
    epochs=num_epochs, 
    batch_size=batch_size, 
    verbose=2
)
# Out:
# Epoch 1/10
# 313/313 - 10s - loss: 1.7089 - accuracy: 0.3816 - val_loss: 1.4977 - val_accuracy: 0.4675 - 10s/epoch - 32ms/step
# Epoch 2/10
# 313/313 - 1s - loss: 1.3978 - accuracy: 0.5039 - val_loss: 1.3643 - val_accuracy: 0.5187 - 1s/epoch - 5ms/step
# Epoch 3/10
# 313/313 - 1s - loss: 1.2823 - accuracy: 0.5443 - val_loss: 1.2821 - val_accuracy: 0.5538 - 1s/epoch - 5ms/step
# Epoch 4/10
# 313/313 - 1s - loss: 1.2102 - accuracy: 0.5704 - val_loss: 1.2153 - val_accuracy: 0.5760 - 1s/epoch - 5ms/step
# Epoch 5/10
# 313/313 - 2s - loss: 1.1462 - accuracy: 0.5972 - val_loss: 1.1975 - val_accuracy: 0.5809 - 2s/epoch - 7ms/step
# Epoch 6/10
# 313/313 - 2s - loss: 1.0943 - accuracy: 0.6170 - val_loss: 1.1734 - val_accuracy: 0.5901 - 2s/epoch - 5ms/step
# Epoch 7/10
# 313/313 - 1s - loss: 1.0489 - accuracy: 0.6328 - val_loss: 1.1489 - val_accuracy: 0.6012 - 1s/epoch - 5ms/step
# Epoch 8/10
# 313/313 - 1s - loss: 1.0078 - accuracy: 0.6462 - val_loss: 1.1233 - val_accuracy: 0.6081 - 1s/epoch - 5ms/step
# Epoch 9/10
# 313/313 - 1s - loss: 0.9653 - accuracy: 0.6631 - val_loss: 1.1899 - val_accuracy: 0.5970 - 1s/epoch - 5ms/step
# Epoch 10/10
# 313/313 - 1s - loss: 0.9407 - accuracy: 0.6707 - val_loss: 1.1203 - val_accuracy: 0.6160 - 1s/epoch - 5ms/step

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  the loss should start around 1.7 and end around 0.9
#  with training accuracy start around 40% and end around 65%

# %% [markdown]
# ---
# ## 5 - Visualize Training History
#
# Visualize the train-validation accuracy

# %%
plot_my_history(history_lenet)

# %% [markdown]
# ---
# ## 6 - Evaluate Model
# Next, let's evaluate the accuracy of the models that have been trained
#
# we should get accuracy around  <font color='blue'>$60\%$</font>

# %%
scores = model_lenet.evaluate(X_test, y_test_hot, verbose=0)

print("\nModel Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Model Accuracy: 60.62%

# %% [markdown]
# ---
# ---
# # [Part 3] AlexNet (2012)
#
# The neural network developed by Krizhevsky, Sutskever, and Hinton in [$2012$](https://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks.pdf) was the coming out party for CNNs in the computer vision community. It is widely regarded as one of the most influential publications in the field
#
# This was the first time a model performed so well on a historically difficult ImageNet dataset. They win the $2012$ ILSVRC and marked the first year where a CNN was used to achieve a top five test error rate of $15.4%$
#
# The network was made up of five conv layers, max-pooling layers, drop-out layers, and three fully connected layers. The network they designed was used for classification with $1,000$ possible categories.
#
# Utilizing techniques that are still used today, such as data augmentation and dropout, this paper really illustrated the benefits of CNNs and backed them up with record breaking performance in the competition.
#
# <br>
#
# <center>
# <img src='https://miro.medium.com/max/1200/1*wzflNwJw9QkjWWvTosXhNw.png' width=750px>

# %% [markdown]
# ---
# ## 1 - Define Model
#
# Define the AlexNet model
#
# The original network is using **custom layer normalization**,
#
# but here, we'll use **Batch Normalization**

# %% [markdown]
# ---
# #### <font color='red'>**EXERCISE:** </font>
#
#     Implement alexnet() function
#     the function will return convolutional neural net with architecture:

# %% [markdown]
# <pre>------------------------------------------------------------------------------------------------------------------------
#                    1                     |                   2                   |                   3
# * the input shape is <font color='blue'><b>227x227x3  </b></font>         | * <b>zero padding 2d</b> with size <font color='blue'><b>2x2</b></font>       | * <b>zero padding 2d</b> with size <font color='blue'><b>1x1</b></font>
# * <b>conv</b> layer with <font color='blue'><b>96</b></font> filters <font color='blue'><b>11x11</b></font>,      | * <b>conv</b> layer with <font color='blue'><b>256</b></font> filters <font color='blue'><b>5x5</b></font>     | * <b>conv</b> layer with <font color='blue'><b>384</b></font> filters of <font color='blue'><b>3x3</b></font>
#   <font color='blue'><b>stride=4</b></font>, using <b>relu</b> activation        |   using <b>relu</b> activation               |   using <b>relu</b> activation
# * <b>max pooling</b> with size <font color='blue'><b>3x3</b></font> and <font color='blue'><b>stride=2</b></font> | * <b>max pooling</b> with size <font color='blue'><b>3x3</b></font>, <font color='blue'><b>stride=2</b></font> |
# * batch normalization layer              | * batch normalization layer           |
#
# ------------------------------------------------------------------------------------------------------------------------
#                    4                     |                   5                   |                   6
# * <b>zero padding 2d</b> with size <font color='blue'><b>1x1</b></font>          | * <b>zero padding 2d</b> with size <font color='blue'><b>1x1</b></font>       | * <b>flatten</b> layer
# * <b>conv</b> layer with <font color='blue'><b>384</b></font> filters <font color='blue'><b>3x3</b></font>        | * <b>conv</b> layer with <font color='blue'><b>256</b></font> filters <font color='blue'><b>3x3</b></font>     | * <b>dense</b> layer with <font color='blue'><b>4096</b></font> neurons
#   using <b>relu</b> activation                  |   using <b>relu</b> activation               |   using <b>relu</b> activation
#                                          | * <b>max pooling</b> with size <font color='blue'><b>3x3</b></font>, <font color='blue'><b>stride=2</b></font> | * <b>dropout</b> layer with <font color='blue'><b>0.5</b></font> probability
#                                          |                                       |
#
# ------------------------------------------------------------------------------------------------------------------------
#                    7                     |                   8                   |
# * <b>dense</b> layer with <font color='blue'><b>4096</b></font> neurons          | * output <b>dense</b> layer with <font color='blue'><b>1000</b></font> neuron |
#   using <b>relu</b> activation                  |   using <b>softmax</b> activation            |
# * <b>dropout</b> layer with <font color='blue'><b>0.5</b></font> probability     |                                       |
#
# ------------------------------------------------------------------------------------------------------------------------

# %%
def alexnet():
    return Sequential([
        # 1 --------------------------------------------------------------------------
        # conv2d 96, 11x11, stride=4, relu, input_shape 227x227x3 
        # maxpool2d 3x3, stride=2 
        # batch normalization 
        Conv2D(96, (11, 11), strides=(4, 4), activation='relu', input_shape=(227, 227, 3)),
        MaxPool2D(pool_size=(3, 3), strides=(2, 2)),
        BatchNormalization(),
        
        # 2 --------------------------------------------------------------------------
        # zeropadding2d 2x2, 
		# conv2d 256, 5x5, relu 
		# maxpool2d 3x3, stride=2
		# batch normalization 
        ZeroPadding2D(padding=(2, 2)),
        Conv2D(256, (5, 5), activation='relu'),
        MaxPool2D(pool_size=(3, 3), strides=(2, 2)),
        BatchNormalization(),
        
        # 3 --------------------------------------------------------------------------
		# zero padding 2d 1x1 
		# conv2d 384, 3x3, relu 
        ZeroPadding2D(padding=(1, 1)),
        Conv2D(384, (3, 3), activation='relu'),
        
        # 4 --------------------------------------------------------------------------
		# zeropadding2d 1x1
		# conv2d 384, 3x3, relu
        ZeroPadding2D(padding=(1, 1)),
        Conv2D(384, (3, 3), activation='relu'),
        
        # 5 --------------------------------------------------------------------------
		# zero padding 2d 1x1 
		# conv2d 256, 3x3, relu 
		# maxpool2d 3x3, stride=2 
        ZeroPadding2D(padding=(1, 1)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPool2D(pool_size=(3, 3), strides=(2, 2)),
        
        # 6 --------------------------------------------------------------------------
		# flatten 
		# dense 4096, relu 
		# dropout 0.5 
        Flatten(),
        Dense(4096, activation='relu'),
        Dropout(0.5),
        
        # 7 --------------------------------------------------------------------------
		# dense 4096, relu 
		# dropout 0.5  
        Dense(4096, activation='relu'),
        Dropout(0.5),
        
        # 8 --------------------------------------------------------------------------
		# dense 1000, softmax 
        Dense(1000, activation='softmax')
        
    ], name="alexnet")

# %% [markdown]
# ---
# ## 2 - Model Summary
# Visualize the model

# %%
model_alex = alexnet()

model_alex.summary()
# Out:
# Model: "alexnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 55, 55, 96)        34944
#
#  max_pooling2d (MaxPooling2D  (None, 27, 27, 96)       0
#  )
#
#  batch_normalization (BatchN  (None, 27, 27, 96)       384
#  ormalization)
#
#  zero_padding2d (ZeroPadding  (None, 31, 31, 96)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 27, 27, 256)       614656
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  zero_padding2d_1 (ZeroPaddi  (None, 15, 15, 256)      0
#  ng2D)
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 384)       885120
#
#  zero_padding2d_2 (ZeroPaddi  (None, 15, 15, 384)      0
#  ng2D)
#
#  conv2d_5 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  zero_padding2d_3 (ZeroPaddi  (None, 15, 15, 384)      0
#  ng2D)
#
#  conv2d_6 (Conv2D)           (None, 13, 13, 256)       884992
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 9216)              0
#
#  dense_7 (Dense)             (None, 4096)              37752832
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_8 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_9 (Dense)             (None, 1000)              4097000
#
# =================================================================
# Total params: 62,379,752
# Trainable params: 62,379,048
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  Total params: 62,379,752
#  Trainable params: 62,379,048
#  Non-trainable params: 704

# %% [markdown]
# ---
# ## 3 - Plot Model
#
# Save model architecture as an image

# %%
plot_model(model_alex, 
           to_file=model_alex.name+'.png', 
           show_shapes=True, 
           show_layer_names=False,
           rankdir='LR',
           dpi=70
          )

# %% [markdown]
# **EXPECTED IMAGE**:
#
# <center>
# <img src="https://i.ibb.co/T4HJfJD/alexnet.png" width="90%"">

# %% [markdown]
# ---
# ---
# # [Part 4] Small AlexNet
#
# AlexNet was originally designed for ImageNet images with input of $227\times227\times3$, which is too big for our **CIFAR-10** dataset
#
# Therefore, for now let's define our **small AlexNet** to classify **CIFAR-10** dataset.
#
# It has the same **5-conv-3-fc** layer, but with $32\times32\times3$ input and $10$ class output

# %% [markdown]
# ---
# ## 1 - Define Model
#
# Define the Small AlexNet model

# %% [markdown]
# ---
# #### <font color='red'>**EXERCISE:** </font>
#
#     Implement alexnet_small() function
#     the function will return convolutional neural net with architecture:

# %% [markdown]
# <pre>------------------------------------------------------------------------------------------------------------------------
#                    1                    |                  2                      |                   3
# * the input shape is <font color='blue'><b>32x32x3</b></font>            | * <b>conv</b> layer with <font color='blue'><b>96</b></font> filters <font color='blue'><b>5x5</b></font>        | * <b>conv</b> layer with <font color='blue'><b>192</b></font> filters of <font color='blue'><b>3x3</b></font>
# * <b>conv</b> layer with <font color='blue'><b>48</b></font> filters <font color='blue'><b>7x7</b></font>,       |   padding=<b>same</b>, using <b>relu</b> activation   |   padding=<b>same</b>, using <b>relu</b>
#   padding=<b>same</b>, using <b>relu</b> activation   | * <b>max pooling</b> with size <font color='blue'><b>2x2, stride=2</b></font>   |
# * <b>max pooling</b> with size <font color='blue'><b>2x2, stride=2</b></font>   | * batch normalization layer             |
# * batch normalization layer             |                                         |
#
# ------------------------------------------------------------------------------------------------------------------------
#                    4                    |                  5                      |                   6
# * <b>conv</b> layer with <font color='blue'><b>192</b></font> filters of <font color='blue'><b>3x3</b></font>    | * <b>conv</b> layer with <font color='blue'><b>256</b></font> filters <font color='blue'><b>3x3</b></font>       | * <b>flatten</b> layer
#   padding=<b>same</b>, using <b>relu</b> activation   |   padding=<b>same</b>, using <b>relu</b> activation   | * <b>dense</b> layer with <font color='blue'><b>512</b></font> neurons
#                                         | * <b>max pooling</b> with size <font color='blue'><b>2x2, stride=2</b></font>   |   using <b>relu</b> activation
#                                         |                                         | * <b>dropout</b> layer with <font color='blue'><b>0.5 prob</b></font>
#                                         |                                         |
# ------------------------------------------------------------------------------------------------------------------------
#                  7                       |                  8                    |
# * <b>dense</b> layer with <font color='blue'><b>256</b></font> neurons           | * output <b>dense</b> layer with <font color='blue'><b>10</b></font> neuron   |
#   using <b>relu</b> activation                  |   using <b>softmax</b> activation            |
# * <b>dropout</b> layer with <font color='blue'><b>0.5</b></font> probability     |                                       |
#
# ------------------------------------------------------------------------------------------------------------------------

# %%
def alexnet_small():
    return Sequential([
        # 1 --------------------------------------------------------------------------
		# conv2d 48 7x7, padding=same, relu, input shape=32x32x3  
		# maxpool2d 2x2, stride=2  
		# batch normalization  
        Conv2D(48, (7, 7), padding='same', activation='relu', input_shape=(32, 32, 3)),
        MaxPool2D(pool_size=(2, 2), strides=2),
        BatchNormalization(),
        
        # 2 --------------------------------------------------------------------------
		# conv2d 96 5x5, relu, padding=same 
		# maxpool2d 2x2, stride=2 
		# batch normalization 
        Conv2D(96, (5, 5), padding='same', activation='relu'),
        MaxPool2D(pool_size=(2, 2), strides=2),
        BatchNormalization(),
        
        # 3 --------------------------------------------------------------------------
        # conv2d 192 3x3, relu, padding=same 
        Conv2D(192, (3, 3), padding='same', activation='relu'),
        
        # 4 --------------------------------------------------------------------------
        # conv2d 192 3x3, relu, padding=same  
        Conv2D(192, (3, 3), padding='same', activation='relu'),
        
        # 5 --------------------------------------------------------------------------
		# conv2d 256 3x3, relu, padding=same  
		# maxpool2d 2x2, stride=2  
        Conv2D(256, (3, 3), padding='same', activation='relu'),
        MaxPool2D(pool_size=(2, 2), strides=2),
        
        # 6 --------------------------------------------------------------------------
        # flatten
		# dense 512, relu 
		# dropout 0.5 
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        
        # 7 --------------------------------------------------------------------------
        # dense 256, relu  
		# dropout 0.5  
        Dense(256, activation='relu'),
        Dropout(0.5),
        
        # 8 --------------------------------------------------------------------------
        # dense 10, softmax 
        Dense(10, activation='softmax'),
        
    ], name="alexnet_small")

# %% [markdown]
# ---
# ## 2 - Model Summary
# Visualize the model

# %%
model_alex_small = alexnet_small()

model_alex_small.summary()
# Out:
# Model: "alexnet_small"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 32, 32, 48)        7104
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 48)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 16, 16, 48)       192
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 96)        115296
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 8, 8, 96)         384
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 192)         166080
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 192)         331968
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 256)         442624
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  flatten_3 (Flatten)         (None, 4096)              0
#
#  dense_10 (Dense)            (None, 512)               2097664
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 256)               131328
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 3,295,210
# Trainable params: 3,294,922
# Non-trainable params: 288
# _________________________________________________________________

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  Total params: 3,295,210
#  Trainable params: 3,294,922
#  Non-trainable params: 288

# %% [markdown]
# ---
# ## 3 - Plot Model
#
# Save model architecture as an image

# %%
plot_model(model_alex_small, 
           to_file=model_alex_small.name+'.png', 
           show_shapes=True, 
           show_layer_names=False,
           rankdir='LR',
           dpi=70
          )

# %% [markdown]
# **EXPECTED IMAGE**:
#
# <center>
# <img src="https://i.ibb.co/jfNTjMP/alexnet-small.png" width="90%"">

# %% [markdown]
# ---
# ## 4 - Train Model
#
#
# Run the training process for `10 epochs`, with `batch size = 128`, using `Adam` Optimizer, and `'accuracy'` as its metric

# %%
num_epochs = 10
batch_size = 128


model_alex_small.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy'])

history_alex_small = model_alex_small.fit(
    X_train, y_train_hot, 
    validation_data=(X_val, y_val_hot),
    epochs=num_epochs, 
    batch_size=batch_size, 
    verbose=2
)
# Out:
# Epoch 1/10
# 313/313 - 11s - loss: 1.6838 - accuracy: 0.3796 - val_loss: 1.3581 - val_accuracy: 0.5113 - 11s/epoch - 35ms/step
# Epoch 2/10
# 313/313 - 5s - loss: 1.2871 - accuracy: 0.5433 - val_loss: 1.1217 - val_accuracy: 0.6039 - 5s/epoch - 17ms/step
# Epoch 3/10
# 313/313 - 5s - loss: 1.0865 - accuracy: 0.6207 - val_loss: 1.0224 - val_accuracy: 0.6489 - 5s/epoch - 17ms/step
# Epoch 4/10
# 313/313 - 5s - loss: 0.9485 - accuracy: 0.6746 - val_loss: 0.9474 - val_accuracy: 0.6709 - 5s/epoch - 17ms/step
# Epoch 5/10
# 313/313 - 5s - loss: 0.8338 - accuracy: 0.7151 - val_loss: 0.8311 - val_accuracy: 0.7133 - 5s/epoch - 17ms/step
# Epoch 6/10
# 313/313 - 5s - loss: 0.7368 - accuracy: 0.7491 - val_loss: 0.7876 - val_accuracy: 0.7292 - 5s/epoch - 18ms/step
# Epoch 7/10
# 313/313 - 6s - loss: 0.6515 - accuracy: 0.7771 - val_loss: 0.7603 - val_accuracy: 0.7451 - 6s/epoch - 18ms/step
# Epoch 8/10
# 313/313 - 5s - loss: 0.5795 - accuracy: 0.8035 - val_loss: 0.7330 - val_accuracy: 0.7593 - 5s/epoch - 17ms/step
# Epoch 9/10
# 313/313 - 6s - loss: 0.5190 - accuracy: 0.8231 - val_loss: 0.7789 - val_accuracy: 0.7464 - 6s/epoch - 18ms/step
# Epoch 10/10
# 313/313 - 5s - loss: 0.4571 - accuracy: 0.8433 - val_loss: 0.8105 - val_accuracy: 0.7472 - 5s/epoch - 17ms/step

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  the loss should start around 1.6 and end around 0.4
#  with training accuracy start around 40% and end around 85%

# %% [markdown]
# ---
# ## 5 - Visualize Training History
#
# Visualize the train-validation accuracy

# %%
plot_my_history(history_alex_small)

# %% [markdown]
# ---
# ## 6 - Evaluate Model
# Next, let's evaluate the accuracy of the models that have been trained
#
# we should get accuracy around  <font color='blue'>$75\%$</font>`

# %%
scores = model_alex_small.evaluate(X_test, y_test_hot, verbose=0)

print("\nModel Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Model Accuracy: 74.18%

# %% [markdown]
# ---
# ---
# # [Part 5] ZF-Net (2013)
#
# ZF Net was not only the winner of the competition in $2013$, but also provided great intuition as to the workings on CNNs and illustrated more ways to improve performance.
# This model achieved an $11.2%$ error rate, which was more of a fine-tuning to the previous AlexNet structure
#
# The authors spent a good amount of time explaining a lot of the intuition behind ConvNets and showing how to visualize the filters and weights correctly.
#
# The fascinating deconv visualization approach and occlusion experiments described helps not only to explain the inner workings of CNNs, but also provides insight for improvements to network architectures.
#
# At this point, Zeiler and Rob Fergus showed the world that CNNs are not black magic which somehow works
#
# <br>
#
# <center>
# <img src='https://adeshpande3.github.io/assets/zfnet.png'  width=800px>
# </center>
#
#
# <br>
# ZF-Net is very similar architecture to AlexNet except for a few minor modifications.
#
# Instead of using $11\times11$ sized filters in the first layer (which is what AlexNet implemented), ZFNet used filters of size $7\times7$ and a decreased stride value.
#
# The reasoning behind this modification is that a smaller filter size in the first conv layer helps retain a lot of original pixel information in the input volume.
#
# A filtering of size $11\times11$ proved to be skipping a lot of relevant information, especially as this is the first conv layer.

# %% [markdown]
# ---
# ## 1 - Define Model
#
# Define the ZFNet model

# %% [markdown]
# ---
# #### <font color='red'>**EXERCISE:** </font>
#
#     Implement zfnet() function
#     the function will return convolutional neural net with architecture:

# %% [markdown]
# <pre>------------------------------------------------------------------------------------------------------------------------
#                    1                    |                   2                    |                   3
# * the input shape is <font color='blue'><b>224x224x3</b></font>          | * <b>conv</b> layer with <font color='blue'><b>256</b></font> filters <font color='blue'><b>5x5 </b></font>     | * <b>conv</b> layer with <font color='blue'><b>384</b></font> filters of <font color='blue'><b>3x3 </b></font>
# * <b>conv</b> layer with <font color='blue'><b>96</b></font> filters <font color='blue'><b>7x7</b></font>,       |   <font color='blue'><b>strides=2</b></font>, using <b>relu</b> activation     |   padding=<b>same</b>, using <b>relu</b>
#   <font color='blue'><b>strides=2</b></font>, using <b>relu</b> activation      | * <b>max pooling</b> with size <font color='blue'><b>3x3</b></font>,           |
# * <b>max pooling</b> with size <font color='blue'><b>3x3</b></font>,            |   <font color='blue'><b>strides=2</b></font>, padding=<b>same</b>              |
#   <font color='blue'><b>strides=2</b></font>, padding=<b>same</b>               | * <b>batch normalization</b> layer            |
# * <b>batch normalization</b> layer             |                                        |
#
# ------------------------------------------------------------------------------------------------------------------------
#                    4                    |                   5                    |                   6
# * <b>conv</b> layer with <font color='blue'><b>384</b></font> filters of <font color='blue'><b>3x3</b></font>    | * <b>conv</b> layer with <font color='blue'><b>256</b></font> filters <font color='blue'><b>3x3</b></font>      | * <b>flatten</b> layer
#   padding=<b>same</b>, using <b>relu</b> activation   |   padding=<b>same</b>, using <b>relu</b> activation  | * <b>dense</b> layer with <font color='blue'><b>4096</b></font> neurons
#                                         | * <b>max pooling</b> with size <font color='blue'><b>3x3, stride=2</b></font>  |   using <b>relu</b> activation
#                                         |                                        | * <b>dropout</b> layer with <font color='blue'><b>0.5 prob</b></font>
#                                         |                                        |
# ------------------------------------------------------------------------------------------------------------------------
#                  7                      |                  8                     |
# * <b>dense</b> layer with <font color='blue'><b>4096</b></font> neurons         | * output <b>dense</b> layer with <font color='blue'><b>1000</b></font> neuron  |
#   using <b>relu</b> activation                 |   using <b>softmax</b> activation             |
# * <b>dropout</b> layer with <font color='blue'><b>0.5</b></font> probability    |                                        |
#
# ------------------------------------------------------------------------------------------------------------------------

# %%
def zfnet():
    return Sequential([
        
        # 1 --------------------------------------------------------------------------
		# conv2d 96 7x7, strides=2, relu, input shape=224x224x3 
		# maxpool2d 3x3, strides=2, padding=same 
		# batch normalization 
        Conv2D(96, (7, 7), strides=(2, 2), activation='relu', input_shape=(224, 224, 3)),
        MaxPool2D((3, 3), strides=(2, 2), padding='same'),
        BatchNormalization(),

        # 2 --------------------------------------------------------------------------
		# conv2d 256 5x5 strides=2, relu 
		# maxpool2d 3x3, strides=2, padding=same 
		# batch normalization 
        Conv2D(256, (5, 5), strides=(2, 2), activation='relu'),
        MaxPool2D((3, 3), strides=(2, 2), padding='same'),
        BatchNormalization(),

        # 3 --------------------------------------------------------------------------
        # conv2d 384 3x3, padding=same, relu 
        Conv2D(384, (3, 3), padding='same', activation='relu'),

        # 4 --------------------------------------------------------------------------
        # conv2d 384 3x3 padding=same, relu 
        Conv2D(384, (3, 3), padding='same', activation='relu'),

        # 5 --------------------------------------------------------------------------
		# conv2d 256 3x3, padding=same, relu 
		# maxpool2d 3x3, stride=2 
        Conv2D(256, (3, 3), padding='same', activation='relu'),
        MaxPool2D((3, 3), strides=(2, 2)),
        
        # 6 --------------------------------------------------------------------------
		# flatten 
		# dense 4096 relu 
		# dropout 0.5 
        Flatten(),
        Dense(4096, activation='relu'),
        Dropout(0.5),

        # 7 --------------------------------------------------------------------------
		# dense 4096 relu 
		# dropout 0.5 
        Dense(4096, activation='relu'),
        Dropout(0.5),
        
        # 8 --------------------------------------------------------------------------
        # dense 1000, softmax 
        Dense(1000, activation='softmax'),
        
    ], name="zfnet")

# %% [markdown]
# ---
# ## 2 - Model Summary
# Visualize the model

# %%
model_zfnet = zfnet()

model_zfnet.summary()
# Out:
# Model: "zfnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 109, 109, 96)      14208
#
#  max_pooling2d_6 (MaxPooling  (None, 55, 55, 96)       0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 55, 55, 96)       384
#  hNormalization)
#
#  conv2d_16 (Conv2D)          (None, 26, 26, 256)       614656
#
#  max_pooling2d_7 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  conv2d_17 (Conv2D)          (None, 13, 13, 384)       885120
#
#  conv2d_18 (Conv2D)          (None, 13, 13, 384)       1327488
#
#  conv2d_19 (Conv2D)          (None, 13, 13, 256)       884992
#
#  max_pooling2d_8 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten_4 (Flatten)         (None, 9216)              0
#
#  dense_13 (Dense)            (None, 4096)              37752832
#
#  dropout_4 (Dropout)         (None, 4096)              0
#
#  dense_14 (Dense)            (None, 4096)              16781312
#
#  dropout_5 (Dropout)         (None, 4096)              0
#
#  dense_15 (Dense)            (None, 1000)              4097000
#
# =================================================================
# Total params: 62,359,016
# Trainable params: 62,358,312
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  Total params: 62,359,016
#  Trainable params: 62,358,312
#  Non-trainable params: 704

# %% [markdown]
# ---
# ## 3 - Plot Model
#
# Save model architecture as an image

# %%
plot_model(model_zfnet, 
           to_file=model_zfnet.name+'.png', 
           show_shapes=True, 
           show_layer_names=False,
           rankdir='LR',
           dpi=70
          )

# %% [markdown]
# **EXPECTED IMAGE**:
#
# <center>
# <img src="https://i.ibb.co/DMKwLqs/zfnet.png" width="90%"">

# %% [markdown]
# ---
# ---
# # [Part 6] VGG Net (2014)
#
# Simplicity and depth, that's what this network is.
#
# [VGG Net](http://arxiv.org/pdf/1409.1556v6.pdf) is one of the most influential papers because it reinforced the notion that convolutional neural networks have to have a deep network of layers in order for this hierarchical representation of visual data to work.
#
# It placed 2nd in ILSVRC 2014 with its 7.3% error rate.
#
# <br>
#
#
# <center>
# <img src='http://www.sanko-shoko.net/note.php?img=y1kl'  width=700px>
#
#   </center>

# %% [markdown]
# The network that was submitted to the competition consist of **5 convolution blocks** and **3 fc layers**.
# <pre>
# Keep it deep. Keep it simple.
# * Each convolution layer uses a <b>3x3</b> filter and <b>padding=1 </b> (same).
# * Each convolution block ends with maxpooling <b>2x2</b>
# * Each layer uses relu activation
# </pre>
#
# <center>
#   <img src='https://www.yjpark.me/assets/expressions/VGG-config.png' width=50%>
# </center>
#
# There are **5 variations** of the network submitted, each with different number of convolution layers in the convolution block.
#
# Each network variation is known by name according to the number of actual layers in the network.
#
#     E.g.
#     * VGG16 has 16 layers (13 conv + 3 fc),
#     * VGG19 has 19 layers (16 conv + 3 fc)

# %% [markdown]
# ---
# ## 1 - Define VGG16 Model
#
# Define the VGG16 model

# %% [markdown]
# ---
# #### <font color='red'>**EXERCISE:** </font>
#
# <pre>
# Implement <b>vgg16()</b> function
# the function will return convolutional neural net with architecture:
#     * Each convolution layer uses a <font color='blue'><b>3x3</b></font> filter and <b>padding='same'</b>.
#     * Each convolution block ends with maxpooling <font color='blue'><b>2x2</b></font>
#     * Each layer uses relu activation

# %% [markdown]
# <pre>------------------------------------------------------------------------------------------------------------------------
#              block 1                               block 2                               block 3
# * the input shape is <font color='blue'><b>224x224x3</b></font>    | * <font color='blue'><b>2x</b></font> <b>conv</b> layer with <font color='blue'><b>128</b></font> filter     | * <font color='blue'><b>3x</b></font> <b>conv</b> layer with <font color='blue'><b>256</b></font> filter
# * <font color='blue'><b>2x</b></font> <b>conv</b> layer with <font color='blue'><b>64</b></font> filter    | * <b>maxpool</b> layer                     |   (4x for vgg19)
# * <b>maxpool</b> layer                   |                                     | * <b>maxpool</b> layer
#
# ------------------------------------------------------------------------------------------------------------------------
#              block 4                               block 5                              FC block 1
# * <font color='blue'><b>3x</b></font> <b>conv</b> layer with <font color='blue'><b>512</b></font> filter   | * <font color='blue'><b>3x</b></font> <b>conv</b> layer with <font color='blue'><b>512</b></font> filter     | * <b>flatten</b> layer
#   (4x for vgg19)                  |   (4x for vgg19)                    | * <b>dense</b> layer with <font color='blue'><b>4096</b></font> neurons
# * <b>maxpool</b> layer                   | * <b>maxpool</b> layer                     | * <b>dropout</b> layer with <font color='blue'><b>0.5 prob</b></font>
#
# ------------------------------------------------------------------------------------------------------------------------
#            FC block 2             |                FC block 3           |
# * <b>dense</b> layer with <font color='blue'><b>4096</b></font> neurons   | * output <b>dense</b> layer <font color='blue'><b>1000</b></font> neuron    |
# * <b>dropout</b> layer with <font color='blue'><b>0.5 prob</b></font>     |   using <b>softmax</b> activation          |
#
# ------------------------------------------------------------------------------------------------------------------------

# %%
def vgg16():
    return Sequential([
        
        # 1-2 (block 1)
		# conv2d 64, input shape=224x224x3
		# conv2d 64
		# maxpool2d  
        Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=(224, 224, 3)),
        Conv2D(64, (3, 3), padding='same', activation='relu'),
        MaxPool2D(pool_size=(2, 2), strides=(2, 2)),

        # 3-4 (block 2)
		# conv2d 128 (2x)
		# maxpool2d 
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        MaxPool2D(pool_size=(2, 2), strides=(2, 2)),

        # 5-7 (block 3)
		# conv2d 256 (3x)
		# maxpool2d 
        Conv2D(256, (3, 3), padding='same', activation='relu'),
        Conv2D(256, (3, 3), padding='same', activation='relu'),
        Conv2D(256, (3, 3), padding='same', activation='relu'),
        MaxPool2D(pool_size=(2, 2), strides=(2, 2)),
        
        # 8-10 (block 4)
		# conv2d 512 (3x)
		# maxpool2d 
        Conv2D(512, (3, 3), padding='same', activation='relu'),
        Conv2D(512, (3, 3), padding='same', activation='relu'),
        Conv2D(512, (3, 3), padding='same', activation='relu'),
        MaxPool2D(pool_size=(2, 2), strides=(2, 2)),

        # 11-13 (block 5)
		# conv2d 512 (3x)
		# maxpool2d 
        Conv2D(512, (3, 3), padding='same', activation='relu'),
        Conv2D(512, (3, 3), padding='same', activation='relu'),
        Conv2D(512, (3, 3), padding='same', activation='relu'),
        MaxPool2D(pool_size=(2, 2), strides=(2, 2)),

        # 14
		# flatten 
		# dense 4096 
		# dropout 0.5 
        Flatten(),
        Dense(4096, activation='relu'),
        Dropout(0.5),
        
        # 15
		# dense 4096 
		# dropout 0.5 
        Dense(4096, activation='relu'),
        Dropout(0.5),
        
        # 16
		# dense 1000, softmax 
        Dense(1000, activation='softmax')
        
    ], name='vgg16')

# %% [markdown]
# ---
# ## 2 - Model Summary
# Visualize the model

# %%
model_vgg = vgg16()

model_vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 224, 224, 64)      1792
#
#  conv2d_23 (Conv2D)          (None, 224, 224, 64)      36928
#
#  max_pooling2d_9 (MaxPooling  (None, 112, 112, 64)     0
#  2D)
#
#  conv2d_24 (Conv2D)          (None, 112, 112, 128)     73856
#
#  conv2d_25 (Conv2D)          (None, 112, 112, 128)     147584
#
#  max_pooling2d_10 (MaxPoolin  (None, 56, 56, 128)      0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_27 (Conv2D)          (None, 56, 56, 256)       590080
#
#  conv2d_28 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_11 (MaxPoolin  (None, 28, 28, 256)      0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  conv2d_30 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  conv2d_31 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  max_pooling2d_12 (MaxPoolin  (None, 14, 14, 512)      0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_33 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_34 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_13 (MaxPoolin  (None, 7, 7, 512)        0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 25088)             0
#
#  dense_16 (Dense)            (None, 4096)              102764544
#
#  dropout_6 (Dropout)         (None, 4096)              0
#
#  dense_17 (Dense)            (None, 4096)              16781312
#
#  dropout_7 (Dropout)         (None, 4096)              0
#
#  dense_18 (Dense)            (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  Total params: 138,357,544
#  Trainable params: 138,357,544
#  Non-trainable params: 0

# %% [markdown]
# ---
# ## 3 - Plot Model
#
# Save model architecture as an image

# %%
plot_model(model_vgg, 
           to_file=model_vgg.name+'.png', 
           show_shapes=True, 
           show_layer_names=False,
           rankdir='LR',
           dpi=70
          )

# %% [markdown]
# **EXPECTED IMAGE**:
#
# <center>
# <img src="https://i.ibb.co/85ZnYcn/vgg16.png" width="90%"">

# %% [markdown]
# ---
# ---
# # [Part 7] Small VGG
#
# Just like we did with AlexNet,
# let's create a vgg_small model to classify the CIFAR-10 dataset
#
# but with $32\times32\times3$ input and $10$ class output, we can only use **3-conv blocks** and **3-fc** layer, instead of 5-conv blocks.
#
# This is due to that the conv block performs maxpool, then after the third max pool, it left us with input size of $4\times4$

# %% [markdown]
# ---
# ## 1 - Define Model
#
# Define the Small VGG model

# %% [markdown]
# ---
# #### <font color='red'>**EXERCISE:** </font>
#
# <pre>
#     Implement <b>vgg_small()</b> function
#     the function will return convolutional neural net with architecture:
#
#     * Each convolution layer uses a <font color='blue'><b>3x3</b></font> filter and <b>padding='same'</b>.
#     * Each convolution block ends with maxpooling <font color='blue'><b>2x2</b></font>
#     * Each layer uses relu activation

# %% [markdown]
# <pre>------------------------------------------------------------------------------------------------------------------------
#              block 1                               block 2                               block 3
# * the input shape is <font color='blue'><b>32x32x3</b></font>      | * <font color='blue'><b>3x</b></font> <b>conv</b> layer with <font color='blue'><b>64</b></font> filter      | * <font color='blue'><b>3x</b></font> <b>conv</b> layer with <font color='blue'><b>128</b></font> filter
# * <font color='blue'><b>3x</b></font> <b>conv</b> layer with <font color='blue'><b>32</b></font> filter    | * <b>maxpool</b> layer                     | * <b>maxpool</b> layer
# * <b>maxpool</b> layer                   |                                     |
#
# ------------------------------------------------------------------------------------------------------------------------
#            FC block 1             |               FC block 2            |              FC block 3
# * <b>flatten</b> layer                   | * <b>dense</b> layer with <font color='blue'><b>256</b></font> neurons      | * output <b>dense</b> layer <font color='blue'><b>10</b></font> neuron
# * <b>dense</b> layer with <font color='blue'><b>512</b></font> neurons    | * <b>dropout</b> layer with <font color='blue'><b>0.5</b></font> prob       |   using <b>softmax</b> activation
# * <b>dropout</b> layer with <font color='blue'><b>0.5</b></font> prob     |                                     |
#
# ------------------------------------------------------------------------------------------------------------------------

# %%
def vgg_small():
    return Sequential([
        
        # 1-3 (block 1)
		# conv2d 32, input shape=32x32x3 
		# conv2d 32
		# conv2d 32
		# maxpool2d 
        Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
        Conv2D(32, (3, 3), padding='same', activation='relu'),
        Conv2D(32, (3, 3), padding='same', activation='relu'),
        MaxPool2D(pool_size=(2, 2)),

        # 4-6 (block 2)
		# conv2d 64 (3x)
		# maxpool2d 
        Conv2D(64, (3, 3), padding='same', activation='relu'),
        Conv2D(64, (3, 3), padding='same', activation='relu'),
        Conv2D(64, (3, 3), padding='same', activation='relu'),
        MaxPool2D(pool_size=(2, 2)),

        # 7-9 (block 3)
		# conv2d 128 (3x)
		# maxpool2d 
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        MaxPool2D(pool_size=(2, 2)),


        # 10
		# flatten 
		# dense 512 
		# dropout 0.5 
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        
        # 11
		# dense 256 
		# dropout 0.5 
        Dense(256, activation='relu'),
        Dropout(0.5),
        
        # 12
		# dense 10, softmax 
        Dense(10, activation='softmax')
        
    ], name='vgg16_small')

# %% [markdown]
# ---
# ## 2 - Model Summary
# Visualize the model

# %%
model_vgg_small = vgg_small()

model_vgg_small.summary()
# Out:
# Model: "vgg16_small"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_35 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 32)        9248
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_14 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 64)        36928
#
#  conv2d_40 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_15 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_42 (Conv2D)          (None, 8, 8, 128)         147584
#
#  conv2d_43 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_16 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 2048)              0
#
#  dense_19 (Dense)            (None, 512)               1049088
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_20 (Dense)            (None, 256)               131328
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_21 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 1,663,754
# Trainable params: 1,663,754
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  Total params: 1,663,754
#  Trainable params: 1,663,754
#  Non-trainable params: 0

# %% [markdown]
# ---
# ## 3 - Plot Model
#
# Save model architecture as an image

# %%
plot_model(model_vgg_small, 
           to_file=model_vgg_small.name+'.png', 
           show_shapes=True, 
           show_layer_names=False,
           rankdir='LR',
           dpi=70
          )

# %% [markdown]
# **EXPECTED IMAGE**:
#
# <center>
# <img src="https://i.ibb.co/CwCmfPk/vgg-small.png" width="90%"">

# %% [markdown]
# ---
# ## 4 - Train Model
#
#
# Run the training process for `10 epochs`, with `batch size = 128`, Adam Optimizer, and `'accuracy'` as its metric

# %%
num_epochs = 10
batch_size = 128

model_vgg_small.compile(loss='categorical_crossentropy', 
                    optimizer='adam', metrics=['accuracy'])

history_vgg_small = model_vgg_small.fit(
    X_train, y_train_hot, 
    validation_data=(X_val, y_val_hot),
    epochs=num_epochs, 
    batch_size=batch_size, 
    verbose=2
)
# Out:
# Epoch 1/10
# 313/313 - 11s - loss: 1.8385 - accuracy: 0.3043 - val_loss: 1.4968 - val_accuracy: 0.4446 - 11s/epoch - 35ms/step
# Epoch 2/10
# 313/313 - 6s - loss: 1.3522 - accuracy: 0.5032 - val_loss: 1.1530 - val_accuracy: 0.5758 - 6s/epoch - 18ms/step
# Epoch 3/10
# 313/313 - 6s - loss: 1.1172 - accuracy: 0.6002 - val_loss: 1.0496 - val_accuracy: 0.6259 - 6s/epoch - 20ms/step
# Epoch 4/10
# 313/313 - 6s - loss: 0.9607 - accuracy: 0.6626 - val_loss: 0.9126 - val_accuracy: 0.6810 - 6s/epoch - 19ms/step
# Epoch 5/10
# 313/313 - 6s - loss: 0.8568 - accuracy: 0.7012 - val_loss: 0.8437 - val_accuracy: 0.7046 - 6s/epoch - 18ms/step
# Epoch 6/10
# 313/313 - 6s - loss: 0.7379 - accuracy: 0.7444 - val_loss: 0.7816 - val_accuracy: 0.7297 - 6s/epoch - 18ms/step
# Epoch 7/10
# 313/313 - 6s - loss: 0.6720 - accuracy: 0.7675 - val_loss: 0.7492 - val_accuracy: 0.7459 - 6s/epoch - 19ms/step
# Epoch 8/10
# 313/313 - 6s - loss: 0.5931 - accuracy: 0.7960 - val_loss: 0.7521 - val_accuracy: 0.7418 - 6s/epoch - 18ms/step
# Epoch 9/10
# 313/313 - 6s - loss: 0.5463 - accuracy: 0.8106 - val_loss: 0.7525 - val_accuracy: 0.7464 - 6s/epoch - 19ms/step
# Epoch 10/10
# 313/313 - 6s - loss: 0.4836 - accuracy: 0.8344 - val_loss: 0.7346 - val_accuracy: 0.7577 - 6s/epoch - 18ms/step

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  the loss should start around 1.8 and end around 0.5
#  with training accuracy start around 30% and end around 83%

# %% [markdown]
# ---
# ## 5 - Visualize Training History
#
# Visualize the train-validation accuracy

# %%
plot_my_history(history_vgg_small)

# %% [markdown]
# ---
# ## 6 - Evaluate Model
# Next, let's evaluate the accuracy of the models that have been trained
#
# we should get accuracy around  <font color='blue'>$75\%$</font>

# %%
scores = model_vgg_small.evaluate(X_test, y_test_hot, verbose=0)

print("\nModel Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Model Accuracy: 75.91%

# %% [markdown]
# **Hey**, it's lower than small AlexNet
#
# But you can see that with small AlexNet, the network starts to overfit even with only 10 epochs.
#
# However with our small VGG, the gap between train and validation is still small, which may indicates that it can still be trained further

# %% [markdown]
# ---
# ---
# # [Part 8] GoogLeNet (2014)
#
# [GoogLeNet](http://arxiv.org/abs/1512.00567) was one of the first models that introduced the idea that CNN layers didn’t always have to be stacked up sequentially.
#
# Coming up with the **Inception module**, the authors showed that a creative structuring of layers can lead to improved performance and computationally efficiency. The authors of the paper emphasized that this new model places notable consideration on memory and power usage.
#
# This paper has really set the stage for some amazing architectures that we could see in the coming years.
#
# <img src='https://adeshpande3.github.io/assets/GoogLeNet.png'>

# %% [markdown]
# The original GoogLeNet uses 9 Inception Module with equivalent with over 100 layers
#
# **That's DEEP**
#
# open this [link](https://adeshpande3.github.io/assets/GoogleNet.gif) to see the detailed gif of the network
# <center>
# <img src='https://adeshpande3.github.io/assets/GoogleNet.gif' width=30%>

# %% [markdown]
# ---
# ## 1 - Inception Module
#
# Building an Inception Module is quite hairy so let's just build the small version for our CIFAR-10
#
# The inception module consist of 4 branches (also called tower) which incorporate three different types of convolution and pooling
#
# <center>
# <img src='https://miro.medium.com/max/1108/1*sezFsYW1MyM9YOMa1q909A.png'>
#
# </center>
#
# To implement it using TensorFlow and Keras, it's better if you use Functional API modelling

# %% [markdown]
# ---
# #### <font color='red'>**EXERCISE:** </font>
# <pre>
# Implement <b>inception()</b> function
# Use <b>Functional API</b>
# Each convolution layer uses <b>relu</b> activation and <b>padding=same</b>.
#
# with input <b>x</b> and number of filter <b>nF</b>, the module consist of 4 branch:
#     * tower 0 = conv with nF filters of 1x1 (x)
#
#     * tower 1 = conv with nF filters of 1x1 (x)
#     * tower 1 = conv with nF filters of 3x3 (tower 1)
#
#     * tower 2 = conv with nF filters of 1x1 (x)
#     * tower 2 = conv with nF filters of 5x5 (tower 2)
#
#     * tower 3 = maxpool 3x3 stride=1 padding=same (x)
#     * tower 3 = conv nF, 1x1 (tower 3)
#
# return the concatenation of all four inputs
# (use tf.keras.layers.concatenate)

# %%
from tensorflow.keras.layers import concatenate

def inception(x, nF):
    '''
    inputs:
    - x : input tensor
    - nF: number of convolution filter

    '''
  
    tower_0 = Conv2D(nF, (1, 1), padding='same', activation='relu')(x)
    
    tower_1 = Conv2D(nF, (1, 1), padding='same', activation='relu')(x)
    tower_1 = Conv2D(nF, (3, 3), padding='same', activation='relu')(tower_1)
    
    tower_2 = Conv2D(nF, (1, 1), padding='same', activation='relu')(x)
    tower_2 = Conv2D(nF, (5, 5), padding='same', activation='relu')(tower_2)
    
    tower_3 = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    tower_3 = Conv2D(nF, (1, 1), padding='same', activation='relu')(tower_3)
    
    output = concatenate([tower_0, tower_1, tower_2, tower_3], axis=3)
    
    output = concatenate([tower_0, tower_1, tower_2, tower_3], axis = 3)
    
    return output

# %% [markdown]
# ---
# ## 2 - Small GoogLeNet Model
#
# Define the Small GoogLeNet model

# %% [markdown]
# ---
# #### <font color='red'>**EXERCISE:** </font>
# <pre>
# Implement <b>googlenet_small()</b> function
# Use <b>Functional API</b>
#
# the function will return convolutional neural net with architecture:
#     * input_img = Input layer with input shape is 32x32x3
#
#     * x = conv layer with 32 filters of 3x3, padding=same and relu activation (input_img)
#     * x = inception module with input x and 32 filters
#     * x = inception module with input x and 64 filters
#     * x = max pool layer (x)
#     * x = inception module with input x and 128 filters
#     * x = inception module with input x and 128 filters
#     * x = global average pooling (x)
#
#     * out = dense layer with 10 neurons and softmax activation (x)
#
# define model from input=input_img to output=out

# %%
def googlenet_small():
    
    # Input layer
    input_img = Input(shape = (32, 32, 3))
    
    # conv layer with 32 filters of 3x3, padding=same and relu activation
    x = Conv2D(32, (3,3), padding='same', activation='relu')(input_img)
    
    # inception module with input x and 32 filters
    x = inception(x, 32)
  
    # inception module with input x and 64 filters
    x = inception(x, 64)
    
    # max pool
    x = MaxPool2D(pool_size=(2,2), strides=(2,2))(x)
    
    # 2x inception module with input x and 128 filters
    x = inception(x, 128)
    x = inception(x, 128)
    
    # global average pooling
    x = GlobalAveragePooling2D()(x)
  
    # output dense of 10 class with softmax activation
    out = Dense(10, activation='softmax')(x)

    model = Model(inputs = input_img, outputs = out, name='googlenet_small')
    
    return model

# %% [markdown]
# ---
# ## 3 - Model Summary
# Visualize the model

# %%
model_googlenet = googlenet_small()

model_googlenet.summary()
# Out:
# Model: "googlenet_small"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_44 (Conv2D)             (None, 32, 32, 32)   896         ['input_1[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 32, 32, 32)   1056        ['conv2d_44[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 32)   1056        ['conv2d_44[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 32, 32, 32)  0           ['conv2d_44[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 32)   1056        ['conv2d_44[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 32)   9248        ['conv2d_46[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 32, 32, 32)   25632       ['conv2d_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 32)   1056        ['max_pooling2d_17[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_45[0][0]',
#                                                                   'conv2d_47[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 32, 32, 64)   8256        ['concatenate_1[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 32, 32, 64)   8256        ['concatenate_1[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 32, 32, 128)  0          ['concatenate_1[0][0]']
#  )
#
#  conv2d_51 (Conv2D)             (None, 32, 32, 64)   8256        ['concatenate_1[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_52[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 32, 32, 64)   102464      ['conv2d_54[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 32, 32, 64)   8256        ['max_pooling2d_18[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_51[0][0]',
#                                                                   'conv2d_53[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 16, 16, 256)  0          ['concatenate_3[0][0]']
#  )
#
#  conv2d_58 (Conv2D)             (None, 16, 16, 128)  32896       ['max_pooling2d_19[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 16, 16, 128)  32896       ['max_pooling2d_19[0][0]']
#
#  max_pooling2d_20 (MaxPooling2D  (None, 16, 16, 256)  0          ['max_pooling2d_19[0][0]']
#  )
#
#  conv2d_57 (Conv2D)             (None, 16, 16, 128)  32896       ['max_pooling2d_19[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_58[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 16, 16, 128)  409728      ['conv2d_60[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 16, 16, 128)  32896       ['max_pooling2d_20[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 16, 16, 512)  0           ['conv2d_57[0][0]',
#                                                                   'conv2d_59[0][0]',
#                                                                   'conv2d_61[0][0]',
#                                                                   'conv2d_62[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 16, 16, 128)  65664       ['concatenate_5[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 16, 16, 128)  65664       ['concatenate_5[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 16, 16, 512)  0          ['concatenate_5[0][0]']
#  )
#
#  conv2d_63 (Conv2D)             (None, 16, 16, 128)  65664       ['concatenate_5[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_64[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 16, 16, 128)  409728      ['conv2d_66[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 16, 16, 128)  65664       ['max_pooling2d_21[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 16, 16, 512)  0           ['conv2d_63[0][0]',
#                                                                   'conv2d_65[0][0]',
#                                                                   'conv2d_67[0][0]',
#                                                                   'conv2d_68[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['concatenate_7[0][0]']
#  alAveragePooling2D)
#
#  dense_22 (Dense)               (None, 10)           5130        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 1,726,410
# Trainable params: 1,726,410
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  Total params: 1,726,410
#  Trainable params: 1,726,410
#  Non-trainable params: 0

# %% [markdown]
# ---
# ## 4 - Plot Model
#
# Save model architecture as an image

# %%
plot_model(model_googlenet, 
           to_file=model_googlenet.name+'.png', 
           show_shapes=True, 
           show_layer_names=False,
           rankdir='LR',
           dpi=55
          )

# %% [markdown]
# **EXPECTED IMAGE**:
#
# <center>
#
#
# <a href="https://i.ibb.co/PCjJMf9/googlenet.png" target="_blank">
#   <img align="center"  src="https://i.ibb.co/PCjJMf9/googlenet.png"/>
# </a>

# %% [markdown]
# ---
# ## 5 - Train Model
#
#
# Run the training process for `10 epochs`, with `batch size = 128`, using `Adam` Optimizer, and `'accuracy'` as its metric

# %%
num_epochs = 10
batch_size = 128

model_googlenet.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy']
)

history_googlenet = model_googlenet.fit(
    X_train, y_train_hot, 
    validation_data=(X_val, y_val_hot),
    epochs=num_epochs, 
    batch_size=batch_size, 
    verbose=2
)
# Out:
# Epoch 1/10
# 313/313 - 49s - loss: 0.3917 - accuracy: 0.8650 - val_loss: 0.5410 - val_accuracy: 0.8207 - 49s/epoch - 157ms/step
# Epoch 2/10
# 313/313 - 39s - loss: 0.3468 - accuracy: 0.8795 - val_loss: 0.6231 - val_accuracy: 0.8001 - 39s/epoch - 125ms/step
# Epoch 3/10
# 313/313 - 39s - loss: 0.3130 - accuracy: 0.8906 - val_loss: 0.5509 - val_accuracy: 0.8178 - 39s/epoch - 126ms/step
# Epoch 4/10
# 313/313 - 42s - loss: 0.2740 - accuracy: 0.9044 - val_loss: 0.5769 - val_accuracy: 0.8162 - 42s/epoch - 133ms/step
# Epoch 5/10
# 313/313 - 42s - loss: 0.2305 - accuracy: 0.9199 - val_loss: 0.5691 - val_accuracy: 0.8251 - 42s/epoch - 133ms/step
# Epoch 6/10
# 313/313 - 40s - loss: 0.2098 - accuracy: 0.9248 - val_loss: 0.5654 - val_accuracy: 0.8336 - 40s/epoch - 127ms/step
# Epoch 7/10
# 313/313 - 39s - loss: 0.1773 - accuracy: 0.9378 - val_loss: 0.6393 - val_accuracy: 0.8267 - 39s/epoch - 126ms/step
# Epoch 8/10
# 313/313 - 42s - loss: 0.1546 - accuracy: 0.9462 - val_loss: 0.5919 - val_accuracy: 0.8369 - 42s/epoch - 133ms/step
# Epoch 9/10
# 313/313 - 42s - loss: 0.1226 - accuracy: 0.9563 - val_loss: 0.6457 - val_accuracy: 0.8326 - 42s/epoch - 133ms/step
# Epoch 10/10
# 313/313 - 40s - loss: 0.1215 - accuracy: 0.9576 - val_loss: 0.6793 - val_accuracy: 0.8288 - 40s/epoch - 126ms/step

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  the loss should start around 1.6 and end around 0.40
#  with training accuracy start around 40% and end around 85%
#  it runs about 90 seconds per epoch

# %% [markdown]
# ---
# ## 6 - Visualize Training History
#
# Visualize the train-validation accuracy

# %%
plot_my_history(history_googlenet)

# %% [markdown]
# ---
# ## 7 - Evaluate Model
# Next, let's evaluate the accuracy of the models that have been trained
#
# we should get accuracy around  <font color='blue'>$79\%$</font>

# %%
scores = model_googlenet.evaluate(X_test, y_test_hot, verbose=0)

print("\nModel Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Model Accuracy: 82.20%

# %% [markdown]
# ---
# ---
# # [Part 9] Residual Network (2015)
#
# 3.6% error rate. That itself should be enough to convince you.
#
# The [ResNet](https://arxiv.org/abs/1512.03385) model is the best CNN architecture that we currently have and is a great innovation for the idea of residual learning.
#
# ResNet is a new 152-layer network architecture that Microsoft Research Asia came up with in late 2015, which set new records in classification, detection, and localization through one incredible architecture
#
#
# <img src='https://adeshpande3.github.io/assets/ResNet.gif' width=300px>

# %% [markdown]
# ---
# ## 1 - Inner Layer
#
# Resnet Inner Layers are the convolution layer inside the skip connection.
#
# There are several combinations for the inner layer troughout resnet.
#
# The combination involves the position of the convolution, presence of activation, and addition of batch norm

# %% [markdown]
# ---
# #### <font color='red'>**EXERCISE:** </font>
# <pre>
# Implement <b>resnet_layer()</b> function
# Use <b>Functional API</b>
#     * conv = <b>Conv2D</b> layer with number of filter, kernel size, and stride according to the input arguments, padding=same
#     * add conv layer according to the conv_first argument
#     * add batchnorm layer according to the batch_normalization argument
#     * add activation layer according to the activation argument

# %%
def resnet_layer(inputs, 
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    
    conv = Conv2D(num_filters, 
                  kernel_size=kernel_size,
                  strides=strides, 
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4)
                 )

    # set x as input
    x = inputs
    
    # if conv_first is true, x = conv (x)
    if conv_first:
        x = conv(x)
        
    # if batch_normalization is true, x = BatchNormalization() (x)
    if batch_normalization:
        x = BatchNormalization()(x)
        
    # if activation is not None, x = Activation(activation) (x)
    if activation is not None:
        x = Activation(activation)(x)
    
    # if conv_first is false, x = conv (x)
    if not conv_first:
        x = conv(x)
        
    return x

# %% [markdown]
# ---
# ## 2 - Small ResNet Model

# %% [markdown]
# ---
# #### <font color='red'>**EXERCISE:** </font>
# <pre>
# Implement <b>resnet_small()</b> function

# %%
def resnet_small(depth = 20):
  
    input_shape = (32, 32, 3)
    
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    # add Input layer
    inputs = Input(shape=input_shape)
    
    # call resnet_layer funtion with inputs=inputs
    x = resnet_layer(inputs=inputs, num_filters=num_filters)
    
    # Instantiate the stack of residual units
    for stack in range(3):
      
        for res_block in range(num_res_blocks):
            
            strides = 1
            
            # check if it is the first layer but not first stack
            if stack > 0 and res_block == 0:
                # downsample for the first layer
                strides = 2
                
            # call resnet_layer function with inputs = x, 
            # num_filters=num_filters, and strides=strides
            y = resnet_layer(inputs=x, num_filters=num_filters, strides=strides)
            
            # call resnet_layer function with inputs = y, 
            # num_filters=num_filters, and activation=None
            y = resnet_layer(inputs=y, num_filters=num_filters, activation=None)
            
            # check if it is the first layer but not first stack
            if stack > 0 and res_block == 0:  
                # linear projection residual shortcut connection to match
                # changed dims
              
                # call resnet_layer function with inputs = x,
                # num_filters=num_filters, kernel_size=1, strides=strides, 
                # activation=None, and batch_normalization=False
                x = resnet_layer(inputs=x, num_filters=num_filters, kernel_size=1, strides=strides, 
                                  activation=None, batch_normalization=False)
                
            # add layer output with the skip connection
            x = tf.keras.layers.add([x, y])
        
            # add relu activation
            x = Activation('relu')(x)
            
        # double the number of filter
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU    
    x = AveragePooling2D(pool_size=8)(x)
    
    # flatten the output average
    y = Flatten()(x)
    
    # create output dense of 10 class with softmax activation
    outputs = Dense(10,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs, name='resnet_small')
    return model

# %% [markdown]
# ---
# ## 3 - Model Summary
# Visualize the model

# %%
model_resnet = resnet_small()

model_resnet.summary()
# Out:
# Model: "resnet_small"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_69 (Conv2D)             (None, 32, 32, 16)   448         ['input_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_69[0][0]']
#  rmalization)
#
#  activation (Activation)        (None, 32, 32, 16)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 32, 32, 16)   2320        ['activation[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_70[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_71[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 16)   0           ['activation[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_2 (Activation)      (None, 32, 32, 16)   0           ['add[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_72[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 16)  64          ['conv2d_73[0][0]']
#  ormalization)
#
#  add_1 (Add)                    (None, 32, 32, 16)   0           ['activation_2[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  activation_4 (Activation)      (None, 32, 32, 16)   0           ['add_1[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_4[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 16)  64          ['conv2d_74[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_5[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 16)  64          ['conv2d_75[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 32, 32, 16)   0           ['activation_4[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 16)   0           ['add_2[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 16, 16, 32)   4640        ['activation_6[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 32)  128         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 16, 16, 32)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_7[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 16, 16, 32)   544         ['activation_6[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 32)  128         ['conv2d_77[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 16, 16, 32)   0           ['conv2d_78[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  activation_8 (Activation)      (None, 16, 16, 32)   0           ['add_3[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_8[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 32)  128         ['conv2d_79[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 16, 16, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_9[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 32)  128         ['conv2d_80[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 16, 16, 32)   0           ['activation_8[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_10 (Activation)     (None, 16, 16, 32)   0           ['add_4[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_10[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 32)  128         ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_11[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 32)  128         ['conv2d_82[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 16, 16, 32)   0           ['activation_10[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  activation_12 (Activation)     (None, 16, 16, 32)   0           ['add_5[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 8, 8, 64)     18496       ['activation_12[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 8, 8, 64)    256         ['conv2d_83[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_19[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_13[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 64)     2112        ['activation_12[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 8, 8, 64)    256         ['conv2d_84[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 8, 8, 64)     0           ['conv2d_85[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_14 (Activation)     (None, 8, 8, 64)     0           ['add_6[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_14[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 64)    256         ['conv2d_86[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_21[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_15[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 64)    256         ['conv2d_87[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 8, 8, 64)     0           ['activation_14[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  activation_16 (Activation)     (None, 8, 8, 64)     0           ['add_7[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_16[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 64)    256         ['conv2d_88[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_23[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_17[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 64)    256         ['conv2d_89[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 8, 8, 64)     0           ['activation_16[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_18 (Activation)     (None, 8, 8, 64)     0           ['add_8[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 1, 1, 64)    0           ['activation_18[0][0]']
#  oling2D)
#
#  flatten_7 (Flatten)            (None, 64)           0           ['average_pooling2d_2[0][0]']
#
#  dense_23 (Dense)               (None, 10)           650         ['flatten_7[0][0]']
#
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  Total params: 274,442
#  Trainable params: 273,066
#  Non-trainable params: 1,376

# %% [markdown]
# ---
# ## 4 - Plot Model
#
# Save model architecture as an image

# %%
plot_model(model_resnet, 
           to_file=model_resnet.name+'.png', 
           show_shapes=True, 
           show_layer_names=False,
           rankdir='TB',
           dpi=55
          )

# %% [markdown]
# ---
# ## 5 - Learning Rate Schedule
#
# before training this network, let's create a custom Adam Optimizer and learning rate scheduling that will periodically decrease the learning rate to improve the accuracy andavoid overfitting

# %% [markdown]
# ---
# ### a. Scheduling Function

# %%
def lr_schedule(epoch):
  
    # initial learning rate
    lr = 1e-3
    
    # check and reduce the learning rate 
    # according to the epoch
    if epoch > 8:
        lr *= 1e-3
    elif epoch > 6:
        lr *= 1e-2
    elif epoch > 4:
        lr *= 1e-1
        
    print('Learning rate: ', lr)
    
    return lr

# %% [markdown]
# ---
# ### b. Scheduling Callback
#
# create a scheduling callback based on the scheduling function

# %%
from tensorflow.keras.callbacks import LearningRateScheduler

lr_callback = LearningRateScheduler(lr_schedule)

# %% [markdown]
# ---
# ### c. Custom Adam Optimizer
#
# create custom Adam Optimizer with initial leraning rate = 0.001

# %%
from tensorflow.keras.optimizers import Adam

myAdam = tf.keras.optimizers.Adam(1e-3)

# %% [markdown]
# ---
# ## 6 - Train Model
#
#
# Run the training process for `10 epochs`, with `batch size = 128`, Adam Optimizer, and `'accuracy'` as its metric

# %%
num_epochs = 10
batch_size = 100

model_resnet.compile(
    loss='categorical_crossentropy', 
    optimizer=myAdam, 
    metrics=['accuracy']
    )

history_resnet = model_resnet.fit(
    X_train, y_train_hot, 
    validation_data=(X_val, y_val_hot),
    epochs=num_epochs, 
    batch_size=batch_size, 
    callbacks=[lr_callback],
    verbose=2)
# Out:
# Learning rate:  0.001
# Epoch 1/10
# 400/400 - 24s - loss: 1.7520 - accuracy: 0.4317 - val_loss: 1.6738 - val_accuracy: 0.4733 - lr: 0.0010 - 24s/epoch - 61ms/step
# Learning rate:  0.001
# Epoch 2/10
# 400/400 - 10s - loss: 1.2545 - accuracy: 0.6037 - val_loss: 1.3818 - val_accuracy: 0.5584 - lr: 0.0010 - 10s/epoch - 25ms/step
# Learning rate:  0.001
# Epoch 3/10
# 400/400 - 10s - loss: 1.0636 - accuracy: 0.6724 - val_loss: 1.1924 - val_accuracy: 0.6412 - lr: 0.0010 - 10s/epoch - 25ms/step
# Learning rate:  0.001
# Epoch 4/10
# 400/400 - 11s - loss: 0.9329 - accuracy: 0.7235 - val_loss: 1.0581 - val_accuracy: 0.6881 - lr: 0.0010 - 11s/epoch - 27ms/step
# Learning rate:  0.001
# Epoch 5/10
# 400/400 - 10s - loss: 0.8288 - accuracy: 0.7633 - val_loss: 1.1342 - val_accuracy: 0.6663 - lr: 0.0010 - 10s/epoch - 25ms/step
# Learning rate:  0.0001
# Epoch 6/10
# 400/400 - 10s - loss: 0.6404 - accuracy: 0.8352 - val_loss: 0.8015 - val_accuracy: 0.7714 - lr: 1.0000e-04 - 10s/epoch - 25ms/step
# Learning rate:  0.0001
# Epoch 7/10
# 400/400 - 10s - loss: 0.5884 - accuracy: 0.8540 - val_loss: 0.8118 - val_accuracy: 0.7710 - lr: 1.0000e-04 - 10s/epoch - 25ms/step
# Learning rate:  1e-05
# Epoch 8/10
# 400/400 - 11s - loss: 0.5494 - accuracy: 0.8681 - val_loss: 0.7889 - val_accuracy: 0.7767 - lr: 1.0000e-05 - 11s/epoch - 27ms/step
# Learning rate:  1e-05
# Epoch 9/10
# 400/400 - 10s - loss: 0.5448 - accuracy: 0.8686 - val_loss: 0.7881 - val_accuracy: 0.7783 - lr: 1.0000e-05 - 10s/epoch - 24ms/step
# Learning rate:  1e-06
# Epoch 10/10
# 400/400 - 10s - loss: 0.5398 - accuracy: 0.8718 - val_loss: 0.7882 - val_accuracy: 0.7786 - lr: 1.0000e-06 - 10s/epoch - 26ms/step

# %% [markdown]
# **EXPECTED OUTPUT**:
# <pre>
#  the loss should start around 1.5 and end around 0.56
#  with training accuracy start around 50% and end around 86%

# %% [markdown]
# ---
# ## 7 - Visualize Training History
#
# Visualize the train-validation accuracy

# %%
plot_my_history(history_resnet)

# %% [markdown]
# ---
# ## 8 - Evaluate Model
# Next, let's evaluate the accuracy of the models that have been trained
#
# we should get accuracy around <font color='blue'>$77\%$</font>

# %%
scores = model_resnet.evaluate(X_test, y_test_hot, verbose=0)

print("\nModel Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Model Accuracy: 77.08%

# %% [markdown]
# ---
#
# # Congratulation, You've Completed Exercise 8
